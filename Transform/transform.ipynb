# %%
import glob                    
import pandas as pd

# %%
path_teams_files = '../Outputs/teams'
extracted_data = []

# %%
def extract_from_csv(file_to_process):
    dataframe = pd.read_csv(file_to_process)
    return dataframe

# %%
# 'goals_scored','goals_conceded','own_goals', 'foul_goals',
# 'penalty_goals','goals_inside_the_area','goal_from_outside_the_area', 
# 'finishing_on_the_post', 'submissions_out','fouls_received', 
# 'fouls_committed', 'offsides','yellow_cards', 'red_cards', 
# 'tough_defenses','penalty_saves', 'ball_steals','wrong_passes'

  # columns=['goals_scored','goals_conceded','own_goals', 'foul_goals',
  # 'penalty_goals','goals_inside_the_area','goal_from_outside_the_area', 
  # 'finishing_on_the_post', 'submissions_out','fouls_received', 
  # 'fouls_committed', 'offsides','yellow_cards', 'red_cards', 
  # 'tough_defenses','penalty_saves', 'ball_steals','wrong_passes']

# %%
def transform():
  
  dic = {}
  
  for csvfile in glob.glob(f"{path_teams_files}/*.csv"):

    current_csv = extract_from_csv(csvfile)
    current_columns = list(current_csv.columns)

    for index, row in current_csv.iterrows():

      list_aux = []
      value1 = int(str(row[1]).replace(".", ""))
      value2 = int(str(row[2]).replace(".", ""))

      try:

        list_aux = dic[row[0]]
        aux_dic = list_aux[0]

        if not (current_columns[1] in aux_dic):
          aux_dic[current_columns[1]] = value1
        
        if not (current_columns[2] in aux_dic):
          aux_dic[current_columns[2]] = value2
         
      except:

        dic[row[0]] = list_aux
        aux_dic = {}
        aux_dic[current_columns[1]] = value1
        aux_dic[current_columns[2]] = value2
        list_aux.append(aux_dic)
 
  return dic

# %%
tt = transform()
# print(tt)
# print(tt['São Paulo'])
# Out:
# 34
# 379
# 34
# 366
# 34
# 363
# 33
# 360
# 34
# 349
# 34
# 348
# 34
# 346
# 34
# 342
# 34
# 340
# 34
# 338
# 34
# 333
# 34
# 323
# 34
# 322
# 35
# 317
# 34
# 310
# 33
# 2.074
# 34
# 1.9269999999999998
# 34
# 1.911
# 34
# 1.87
# 33
# 1.829
# 34
# 1.824
# 34
# 1.811
# 34
# 1.7619999999999998
# 34
# 1.761
# 34
# 1.755
# 34
# 1.744
# 34
# 1.74
# 34
# 1.7080000000000002
# 35
# 1.6980000000000002
# 34
# 1.66
# 33
# 1
# 34
# 1
# 34
# 1
# 34
# 1
# 34
# 1
# 34
# 1
# 34
# 1
# 35
# 1
# 34
# 0
# 34
# 0
# 34
# 0
# 34
# 541
# 33
# 503
# 34
# 496
# 35
# 487
# 34
# 468
# 34
# 462
# 34
# 460
# 34
# 456
# 34
# 451
# 34
# 445
# 34
# 438
# 34
# 437
# 34
# 418
# 34
# 411
# 34
# 408
# 33
# 430
# 34
# 410
# 34
# 362
# 34
# 360
# 34
# 351
# 34
# 351
# 34
# 350
# 33
# 349
# 34
# 343
# 34
# 342
# 34
# 340
# 34
# 339
# 33
# 336
# 34
# 336
# 34
# 336
# 33
# 1
# 33
# 1
# 34
# 1
# 34
# 1
# 34
# 1
# 34
# 1
# 34
# 1
# 34
